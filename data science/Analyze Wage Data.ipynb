# %% [markdown]
# # Analyze Wage Data with Python
#
# - [View Solution Notebook](./solutions.html)
# - [View Project Page](https://www.codecademy.com/projects/practice/analyze-wage-data-with-python)

# %% [markdown]
# ## Task Group 1 - Import and Clean

# %% [markdown]
# ### Task 1
#
# Display the first five lines of `df_wages`.

# %%
import pandas as pd

df_wages = pd.read_csv('wages.csv')

# Preview the data
df_wages.head()
# Out:
#    Index Occupation title (click on the occupation title to view its profile)  \
# 0      0  Management Occupations - Top Executives - Chie...
# 1      1  Management Occupations - Top Executives - Gene...
# 2      2  Management Occupations - Top Executives - Legi...
# 3      3  Management Occupations - Advertising, Marketin...
# 4      4  Management Occupations - Advertising, Marketin...
#
#    Year  Employment Average hourly wage Industry average  \
# 0  2021      200480             $102.41           $59.31
# 1  2021     2984920              $55.41           $59.31
# 2  2021       44590                 NaN           $59.31
# 3  2021       22520              $68.68           $59.31
# 4  2021      278690              $73.77           $59.31
#
#   Similar occupation average
# 0                     $57.94
# 1                     $57.94
# 2                     $57.94
# 3                     $69.77
# 4                     $69.77

# %% [markdown]
# ### Task 2
#
# Rename the `Occupation title (click on the occupation title to view its profile)` column to `Occupation title`.

# %%
df_wages = df_wages.rename(
    mapper={'Occupation title (click on the occupation title to view its profile)': 'Occupation title'}, axis=1)

# show output
df_wages.head()
# Out:
#    Index                                   Occupation title  Year  Employment  \
# 0      0  Management Occupations - Top Executives - Chie...  2021      200480
# 1      1  Management Occupations - Top Executives - Gene...  2021     2984920
# 2      2  Management Occupations - Top Executives - Legi...  2021       44590
# 3      3  Management Occupations - Advertising, Marketin...  2021       22520
# 4      4  Management Occupations - Advertising, Marketin...  2021      278690
#
#   Average hourly wage Industry average Similar occupation average
# 0             $102.41           $59.31                     $57.94
# 1              $55.41           $59.31                     $57.94
# 2                 NaN           $59.31                     $57.94
# 3              $68.68           $59.31                     $69.77
# 4              $73.77           $59.31                     $69.77

# %% [markdown]
# ### Task 3
#
# Drop any redundant or otherwise unnecessary columns from `df_wages`. Make a note of why these columns are suitable for dropping!

# %%
df_wages = df_wages.drop(
    labels=['Index', 'Year'], 
    axis=1)

# show output
df_wages.head()
# Out:
#                                     Occupation title  Employment  \
# 0  Management Occupations - Top Executives - Chie...      200480
# 1  Management Occupations - Top Executives - Gene...     2984920
# 2  Management Occupations - Top Executives - Legi...       44590
# 3  Management Occupations - Advertising, Marketin...       22520
# 4  Management Occupations - Advertising, Marketin...      278690
#
#   Average hourly wage Industry average Similar occupation average
# 0             $102.41           $59.31                     $57.94
# 1              $55.41           $59.31                     $57.94
# 2                 NaN           $59.31                     $57.94
# 3              $68.68           $59.31                     $69.77
# 4              $73.77           $59.31                     $69.77

# %% [markdown]
# ### Task 4
#
# Display column information including names, # non-null entries, and data types.

# %%
df_wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Occupation title            824 non-null    object
#  1   Employment                  824 non-null    int64
#  2   Average hourly wage         764 non-null    object
#  3   Industry average            824 non-null    object
#  4   Similar occupation average  765 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 32.3+ KB

# %% [markdown]
# ## Task Group 2 - Column Transformations

# %% [markdown]
# ### Task 5
#
# Use pandas to split the information in the `Occupation title` column into new columns `Industry`, `Level`, and `Occupation`.

# %%
df_occupation_split = df_wages['Occupation title'].str.split(
    pat='-',
    expand=True)

df_wages['Industry'] = df_occupation_split[0]
df_wages['Level'] = df_occupation_split[1]
df_wages['Occupation'] = df_occupation_split[2]

# show output
df_wages[['Occupation title', 'Industry', 'Level', 'Occupation']].head()
# Out:
#                                     Occupation title                 Industry  \
# 0  Management Occupations - Top Executives - Chie...  Management Occupations
# 1  Management Occupations - Top Executives - Gene...  Management Occupations
# 2  Management Occupations - Top Executives - Legi...  Management Occupations
# 3  Management Occupations - Advertising, Marketin...  Management Occupations
# 4  Management Occupations - Advertising, Marketin...  Management Occupations
#
#                                                Level  \
# 0                                    Top Executives
# 1                                    Top Executives
# 2                                    Top Executives
# 3   Advertising, Marketing, Promotions, Public Re...
# 4   Advertising, Marketing, Promotions, Public Re...
#
#                              Occupation
# 0                      Chief Executives
# 1       General and Operations Managers
# 2                           Legislators
# 3   Advertising and Promotions Managers
# 4                    Marketing Managers

# %% [markdown]
# ### Task 6
#
# Remove any leading and trailing whitespaces in the columns `Industry`, `Level`, and `Occupation`.

# %%
df_wages['Industry'] = df_wages['Industry'].str.strip()
df_wages['Level'] = df_wages['Level'].str.strip()
df_wages['Occupation'] = df_wages['Occupation'].str.strip()

# %% [markdown]
# ### Task 7
#
# Replace the `'$'` character in the columns `Average hourly wage`, `Industry average`, and `Similar occupation average` with an empty character `''` (no space between the single quotes!).

# %%
df_wages['Average hourly wage'] = df_wages['Average hourly wage'].str.replace(
    pat='$', repl='', regex=False)

df_wages['Industry average'] = df_wages['Industry average'].str.replace(
    pat='$', repl='', regex=False)

df_wages['Similar occupation average'] = df_wages['Similar occupation average'].str.replace(
    pat='$', repl='', regex=False)

# show output
df_wages[['Average hourly wage', 'Industry average', 'Similar occupation average']].head()
# Out:
#   Average hourly wage Industry average Similar occupation average
# 0              102.41            59.31                      57.94
# 1               55.41            59.31                      57.94
# 2                 NaN            59.31                      57.94
# 3               68.68            59.31                      69.77
# 4               73.77            59.31                      69.77

# %% [markdown]
# ### Task 8
#
# Convert the data types of the columns `Average hourly wage`, `Industry average`, and `Similar occupation average` from `object` to `float`.

# %%
df_wages[['Average hourly wage', 'Industry average', 'Similar occupation average']] = df_wages[['Average hourly wage', 'Industry average', 'Similar occupation average']].astype('float')

# show output
df_wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Occupation title            824 non-null    object
#  1   Employment                  824 non-null    int64
#  2   Average hourly wage         764 non-null    float64
#  3   Industry average            824 non-null    float64
#  4   Similar occupation average  765 non-null    float64
#  5   Industry                    824 non-null    object
#  6   Level                       824 non-null    object
#  7   Occupation                  824 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 51.6+ KB

# %% [markdown]
# ## Task Group 3 - Comparison to Industry Average

# %% [markdown]
# ### Task 9
#
# Calculate the difference between the average hourly wage and the industry average. Assign the difference to a new column `Industry wage difference`.

# %%
df_wages['Industry wage difference'] = df_wages['Average hourly wage'] - df_wages['Industry average']

# show output
df_wages[['Occupation', 'Average hourly wage', 'Industry average', 'Industry wage difference']].head()
# Out:
#                             Occupation  Average hourly wage  Industry average  \
# 0                     Chief Executives               102.41             59.31
# 1      General and Operations Managers                55.41             59.31
# 2                          Legislators                  NaN             59.31
# 3  Advertising and Promotions Managers                68.68             59.31
# 4                   Marketing Managers                73.77             59.31
#
#    Industry wage difference
# 0                     43.10
# 1                     -3.90
# 2                       NaN
# 3                      9.37
# 4                     14.46

# %% [markdown]
# ### Task 10
#
# Divide `Industry wage difference` by `Industry average` to convert the difference to a percent change. (You might want to multiply by `100` at the end to display as a percentage).
#
# Assign the result to new column called `Industry wage pctchg`.

# %%
df_wages['Industry wage pctchg'] = (df_wages['Industry wage difference'] / df_wages['Industry average']) * 100

# show output
df_wages[['Industry', 'Occupation','Level', 'Average hourly wage', 'Industry average', 'Industry wage pctchg']].head()
# Out:
#                  Industry                           Occupation  \
# 0  Management Occupations                     Chief Executives
# 1  Management Occupations      General and Operations Managers
# 2  Management Occupations                          Legislators
# 3  Management Occupations  Advertising and Promotions Managers
# 4  Management Occupations                   Marketing Managers
#
#                                                Level  Average hourly wage  \
# 0                                     Top Executives               102.41
# 1                                     Top Executives                55.41
# 2                                     Top Executives                  NaN
# 3  Advertising, Marketing, Promotions, Public Rel...                68.68
# 4  Advertising, Marketing, Promotions, Public Rel...                73.77
#
#    Industry average  Industry wage pctchg
# 0             59.31             72.669027
# 1             59.31             -6.575620
# 2             59.31                   NaN
# 3             59.31             15.798348
# 4             59.31             24.380374

# %% [markdown]
# ### Task 11
#
# Sort `df_wages` by the `Industry wage pctchg` column from *highest* to *lowest*. Assign the result to the variable `highest_industry_pctchg`.

# %%
highest_industry_pctchg = df_wages.sort_values(
    by='Industry wage pctchg',
    ascending=False)

# show output
highest_industry_pctchg[['Industry', 'Occupation','Level', 'Industry wage pctchg']].head(10)
# Out:
#                                               Industry  \
# 329  Healthcare Practitioners and Technical Occupat...
# 460              Personal Care and Service Occupations
# 328  Healthcare Practitioners and Technical Occupat...
# 305  Healthcare Practitioners and Technical Occupat...
# 331  Healthcare Practitioners and Technical Occupat...
# 342  Healthcare Practitioners and Technical Occupat...
# 330  Healthcare Practitioners and Technical Occupat...
# 339  Healthcare Practitioners and Technical Occupat...
# 344  Healthcare Practitioners and Technical Occupat...
# 335  Healthcare Practitioners and Technical Occupat...
#
#                                      Occupation  \
# 329                               Cardiologists
# 460  Makeup Artists, Theatrical and Performance
# 328                           Anesthesiologists
# 305             Oral and Maxillofacial Surgeons
# 331               Emergency Medicine Physicians
# 342       Orthopedic Surgeons, Except Pediatric
# 330                              Dermatologists
# 339                                Radiologists
# 344                         Surgeons, All Other
# 335             Obstetricians and Gynecologists
#
#                                                Level  Industry wage pctchg
# 329  Healthcare Diagnosing or Treating Practitioners            288.538813
# 460                      Personal Appearance Workers            269.820656
# 328  Healthcare Diagnosing or Treating Practitioners            263.515982
# 305  Healthcare Diagnosing or Treating Practitioners            241.872146
# 331  Healthcare Diagnosing or Treating Practitioners            240.981735
# 342  Healthcare Diagnosing or Treating Practitioners            236.118721
# 330  Healthcare Diagnosing or Treating Practitioners            232.305936
# 339  Healthcare Diagnosing or Treating Practitioners            231.187215
# 344  Healthcare Diagnosing or Treating Practitioners            226.872146
# 335  Healthcare Diagnosing or Treating Practitioners            225.136986

# %% [markdown]
# ## Task Group 4 - Computer Jobs

# %% [markdown]
# ### Task 12
#
# Use the separate `Industry` column you created in Task 5 to investigate occupations in the **'Computer and Mathematical Occupations'** industry. Filter `df_wages` for this specific industry and create a new DataFrame named `cs_math_occupations`.

# %%
is_cs_math = df_wages['Industry'] == 'Computer and Mathematical Occupations'
cs_math_occupations = df_wages[is_cs_math]

# %% [markdown]
# ### Task 13
#
# Sort `cs_math_occupations` by `Average hourly wage` from highest to lowest, and display the results.

# %%
cs_math_occupations = cs_math_occupations.sort_values(
    by='Average hourly wage',
    ascending=False)

cs_math_occupations
# Out:
#                                      Occupation title  Employment  \
# 70  Computer and Mathematical Occupations - Comput...       30840
# 83  Computer and Mathematical Occupations - Mathem...       23040
# 75  Computer and Mathematical Occupations - Comput...       50440
# 78  Computer and Mathematical Occupations - Comput...     1364180
# 73  Computer and Mathematical Occupations - Comput...      168830
# 69  Computer and Mathematical Occupations - Comput...      157220
# 84  Computer and Mathematical Occupations - Mathem...        1770
# 87  Computer and Mathematical Occupations - Mathem...      105980
# 68  Computer and Mathematical Occupations - Comput...      505150
# 86  Computer and Mathematical Occupations - Mathem...       31370
# 82  Computer and Mathematical Occupations - Comput...      370190
# 79  Computer and Mathematical Occupations - Comput...      190120
# 77  Computer and Mathematical Occupations - Comput...      152610
# 74  Computer and Mathematical Occupations - Comput...       85870
# 85  Computer and Mathematical Occupations - Mathem...       98700
# 81  Computer and Mathematical Occupations - Comput...       82380
# 76  Computer and Mathematical Occupations - Comput...      316760
# 80  Computer and Mathematical Occupations - Comput...       84820
# 88  Computer and Mathematical Occupations - Mathem...        3970
# 71  Computer and Mathematical Occupations - Comput...      176200
# 72  Computer and Mathematical Occupations - Comput...      654310
#
#     Average hourly wage  Industry average  Similar occupation average  \
# 70                68.58             48.01                       47.89
# 83                60.24             48.01                       49.90
# 75                58.58             48.01                       47.89
# 78                58.17             48.01                       47.89
# 73                58.01             48.01                       47.89
# 69                54.46             48.01                       47.89
# 84                54.05             48.01                       49.90
# 87                52.24             48.01                       49.90
# 68                49.14             48.01                       47.89
# 86                47.81             48.01                       49.90
# 82                47.20             48.01                       47.89
# 79                46.97             48.01                       47.89
# 77                46.46             48.01                       47.89
# 74                46.42             48.01                       47.89
# 85                46.07             48.01                       49.90
# 81                45.90             48.01                       47.89
# 76                43.87             48.01                       47.89
# 80                39.09             48.01                       47.89
# 88                37.48             48.01                       49.90
# 71                34.30             48.01                       47.89
# 72                27.72             48.01                       47.89
#
#                                  Industry                             Level  \
# 70  Computer and Mathematical Occupations              Computer Occupations
# 83  Computer and Mathematical Occupations  Mathematical Science Occupations
# 75  Computer and Mathematical Occupations              Computer Occupations
# 78  Computer and Mathematical Occupations              Computer Occupations
# 73  Computer and Mathematical Occupations              Computer Occupations
# 69  Computer and Mathematical Occupations              Computer Occupations
# 84  Computer and Mathematical Occupations  Mathematical Science Occupations
# 87  Computer and Mathematical Occupations  Mathematical Science Occupations
# 68  Computer and Mathematical Occupations              Computer Occupations
# 86  Computer and Mathematical Occupations  Mathematical Science Occupations
# 82  Computer and Mathematical Occupations              Computer Occupations
# 79  Computer and Mathematical Occupations              Computer Occupations
# 77  Computer and Mathematical Occupations              Computer Occupations
# 74  Computer and Mathematical Occupations              Computer Occupations
# 85  Computer and Mathematical Occupations  Mathematical Science Occupations
# 81  Computer and Mathematical Occupations              Computer Occupations
# 76  Computer and Mathematical Occupations              Computer Occupations
# 80  Computer and Mathematical Occupations              Computer Occupations
# 88  Computer and Mathematical Occupations  Mathematical Science Occupations
# 71  Computer and Mathematical Occupations              Computer Occupations
# 72  Computer and Mathematical Occupations              Computer Occupations
#
#                                          Occupation  Industry wage difference  \
# 70     Computer and Information Research Scientists                     20.57
# 83                                        Actuaries                     12.23
# 75                              Database Architects                     10.57
# 78                              Software Developers                     10.16
# 73                      Computer Network Architects                     10.00
# 69                    Information Security Analysts                      6.45
# 84                                   Mathematicians                      6.04
# 87                                  Data Scientists                      4.23
# 68                        Computer Systems Analysts                      1.13
# 86                                    Statisticians                     -0.20
# 82                  Computer Occupations, All Other                     -0.81
# 79  Software Quality Assurance Analysts and Testers                     -1.04
# 77                             Computer Programmers                     -1.55
# 74                          Database Administrators                     -1.59
# 85                     Operations Research Analysts                     -1.94
# 81              Web and Digital Interface Designers                     -2.11
# 76      Network and Computer Systems Administrators                     -4.14
# 80                                   Web Developers                     -8.92
# 88      Mathematical Science Occupations, All Other                    -10.53
# 71             Computer Network Support Specialists                    -13.71
# 72                Computer User Support Specialists                    -20.29
#
#     Industry wage pctchg
# 70             42.845241
# 83             25.473860
# 75             22.016247
# 78             21.162258
# 73             20.828994
# 69             13.434701
# 84             12.580712
# 87              8.810664
# 68              2.353676
# 86             -0.416580
# 82             -1.687149
# 79             -2.166215
# 77             -3.228494
# 74             -3.311810
# 85             -4.040825
# 81             -4.394918
# 76             -8.623203
# 80            -18.579463
# 88            -21.932931
# 71            -28.556551
# 72            -42.262029
